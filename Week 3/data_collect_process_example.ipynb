# %% [markdown]
# 충분히 풀 수 있습니다~ 저번보다 훨씬 쉬워요
#
# 화이팅!!
#
# ![image](https://image.fmkorea.com/files/attach/new2/20210919/4168377/3377875027/3927002519/99b983892094b5c6d2fc3736e15da7d1.jpg)

# %% [markdown]
# ---

# %%
import pandas as pd
import sqlite3

# %% [markdown]
# ## 1 ~ 4번 문제
#
# - 주가 데이터 활용

# %% [markdown]
# ### 1. 원하는 2가지 주식 종목의 2010년부터의 주가 데이터를 불러오고, Sqlite에 각각 저장하세요.
#
# - 권장) 2개 종목은 국내 종목, 해외 종목 중 하나로 통일하세요 (화폐 단위의 통일을 위해)

# %%
import FinanceDataReader as fdr

# 한국거래소 상장 데이터
df_krx = fdr.StockListing('KRX')

# 나스닥 상장 데이터
df_ndq = fdr.StockListing('NASDAQ')
# Out:
# 100%|██████████| 3952/3952 [00:19<00:00, 198.61it/s]

# %% [markdown]
# - 위 데이터프레임에서 원하는 종목의 코드를 확인하세요

# %%
# 밑에 코드 작성

# %% [markdown]
# ### 2. Sqlite에 저장한 두 주가 데이터를 로드해 데이터프레임으로 저장한 후, Close 컬럼만 뽑아 한 데이터프레임으로 합치세요.
#
# > 두 컬럼명은 각 주가의 종목명으로 변경

# %%
# 밑에 코드 작성

# %% [markdown]
# - 정답 예시
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3. 두 종목의 시간 간격을 재조정하여 년별 평균 주가를 구하고, 어떤 종목에 투자하는게 더 좋았을지 확인하세요. (Pandas - 4.8 참고)

# %%
# 아래 주석을 풀어 위에 정의한 데이터프레임의 정보를 출력하세요
## apple_nvidia.info()

# %% [markdown]
# - 인덱스가 datetime 타입이 아닌 것을 확인할 수 있음

# %%
# 아래 주석을 풀어 인덱스를 datetime 타입으로 변경하세요
## apple_nvidia.index = pd.to_datetime(apple_nvidia.index)

# %%
# 밑에 코드 작성

# %% [markdown]
# - 정답 예시
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 4. 두 종목의 주가를 아래 3가지 방법으로 스케일링하고, 각 방법에 대해 설명하세요. (데이터 전처리 - 2.1 참고)
#
# 1. StandardScaler()
# 2. RobustScaler()
# 3. MinMaxScaler()

# %%
from sklearn.preprocessing import StandardScaler

# 밑에 코드 작성

# %% [markdown]
# ---

# %% [markdown]
# ## 5 ~ 6번 문제
#
# - 자율적으로 데이터 수집 후 활용

# %% [markdown]
# ### 5. 카테고리 변수가 존재하는 데이터를 수집하여, 더미변수화하세요.

# %% [markdown]
# ### 6. 각 변수의 결측치를 missingno 패키지를 통해 확인하세요.
